# %% [markdown]
# # Project Title : Top 100 YouTube Channels in 2024

# %% [markdown]
# # About Dataset
# This dataset showcases the top 100 YouTube channels in 2024, including key metrics such as subscribers, total views, and video count. It has been manually curated to provide a snapshot of the leading channels as of December 2024. The data reflects the performance of channels across various genres, from entertainment to educational content, offering insights into the most influential creators of the year. This data is useful for marketers, content creators, and data scientists who want to analyze trends, audience engagement, and growth strategies of top YouTube influencers. By examining these metrics, users can gain valuable insights into content creation, viewer preferences, and platform dynamics. The dataset is based on publicly available YouTube statistics and third-party platforms, ensuring transparency and accuracy.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Dataset
data = pd.read_csv('YOUTUBE CHANNELS DATASET.csv')

# %%
data
# Out:
#      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100      NaN                       NaN         NaN      NaN              NaN
#
#     Country
# 0        US
# 1        IN
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Check for missing values
print("Missing Values:\n", data.isnull().sum())
# Out:
# Missing Values:
#  Ranking        1
# Username       1
# Subscribers    1
# Uploads        1
# Views          1
# Country        7
# dtype: int64

# %%
# Fill missing numerical values with the median
data.fillna(data.median(numeric_only=True), inplace=True)
data
# Out:
#      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100     50.5                       NaN         NaN      NaN              NaN
#
#     Country
# 0        US
# 1        IN
# ...

# %%
# Drop duplicate rows
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100     50.5                       NaN         NaN      NaN              NaN
#
#     Country
# 0        US
# 1        IN
# ...

# %%
# Standardize column names and data formats(e.g., dates,numerical values)
data.columns = data.columns.str.strip().str.replace(' ','_')

# %%
data
# Out:
#      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100     50.5                       NaN         NaN      NaN              NaN
#
#     Country
# 0        US
# 1        IN
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# Exploratory Data Analysis (EDA) is the process of analyzing a dataset to summarize its main characteristics, uncover patterns, detect anomalies, test hypotheses, and check assumptions using statistical and graphical techniques. It is often the first step in any data analysis or data science project and helps you understand the data better before applying models or making decisions.

# %%
# Summary statistics
data.describe()
# Out:
#          Ranking
# count  101.00000
# mean    50.50000
# std     28.86607
# min      1.00000
# 25%     26.00000
# 50%     50.50000
# 75%     75.00000
# max    100.00000

# %%
# Top 10 Channels by Subscribers
top_channels = data.sort_values('Subscribers', ascending=True).head(10)

# %%
print("Top 10 Channels by Subscribers:\n", top_channels[['Username', 'Subscribers']])
# Out:
# Top 10 Channels by Subscribers:
#               Username Subscribers
# 13          Goldmines        101M
# 12       Stokes Twins        102M
# 11                WWE        106M
# 10          PewDiePie        110M
# 9   Zee Music Company        112M
# 8               Music        121M
# 7         Like Nastya        124M
# 6     Kids Diana Show        128M
# 5         Vlad & Niki        129M
# 4           Set India        180M

# %%
# Bar chart for top channels
plt.figure(figsize=(10,6))
plt.barh(top_channels['Username'],top_channels['Subscribers'],color='blue')
plt.xlabel('Subscribers')
plt.title('Top 10 Channels by Subscribers')
plt.ylabel('Username')
plt.show()

# %%
# correlation heatmap
numeric_data = data.select_dtypes(include=['number'])
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
# Distribution of views
plt.figure(figsize=(8, 5))
sns.histplot(data['Views'], bins=30, kde=True, color='green')
plt.title('Distribution of Views')
plt.xlabel('Views')
plt.ylabel('Frequency')
plt.show()

# %%
print(data['Uploads'].unique())
# Out:
# ['838' '22,313' '1370' '0' '148,727' '796' '1,282' '918' '12,787' '4,800'
#  '80,964' '335' '9,421' '94,136' '603' '832' '190,672' '7,391' '2,674'
#  '3,399' '179,052' '2,253' '249' '3,580' '29,140' '80' '971' '6,859'
#  '8,988' '1,413' '19,224' '415,087' '1,396' '3,014' '1,667' '731' '20,481'
#  '196' '152,148' '41,711' '5,941' '4,333' '2,873' '187' '463' '285'
#  '1,435' '155,545' '933' '1,221' '508' '2,655' '13,166' '1,143' '1,158'
#  '538' '214' '11,966' '142' '3,468' '2,072' '3,688' '2,009' '2,909'
#  '2,264' '1,070' '234,889' '6,907' '111,513' '9,550' '3,028' '1,735'
#  '2,915' '636' '157' '547' '4,792' '4,763' '24,021' '1,857' '123' '362'
#  '1,921' '1,193' '5,310' '1,334' '3,201' '433,181' '916' '676' '314' '141'
#  '1,831' '1,714' '170' '11,880' '1,861' nan]

# %%
data['Uploads'] = pd.to_numeric(data['Uploads'], errors='coerce')

# %%
data
# Out:
#      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M    838.0   66,853,633,536
# 1        2.0                  T-Series        281M      NaN  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M   1370.0  194,361,752,276
# 3        4.0            Youtube Movies        185M      0.0                0
# 4        5.0                 Set India        180M      NaN  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M      NaN    8,180,068,059
# 97      98.0                Katy Perry       45.6M    170.0   27,616,850,074
# 98      99.0             Speed Records       45.5M      NaN   30,587,436,800
# 99     100.0                     Zhong       45.5M      NaN   17,998,163,730
# 100     50.5                       NaN         NaN      NaN              NaN
#
#     Country
# 0        US
# 1        IN
# ...

# %%
print(data[data['Uploads'].isna()])
# Out:
#      Ranking           Username Subscribers  Uploads            Views Country
# 1        2.0           T-Series        281M      NaN  277,242,795,553      IN
# 4        5.0          Set India        180M      NaN  172,709,029,653      IN
# 6        7.0    Kids Diana Show        128M      NaN  108,987,929,584      US
# 9       10.0  Zee Music Company        112M      NaN   72,091,345,721      IN
# 10      11.0          PewDiePie        110M      NaN   29,453,929,047      JP
# ..       ...                ...         ...      ...              ...     ...
# 95      96.0      Alfredo Larin         46M      NaN   39,518,875,780      SV
# 96      97.0         Voce Sabia         46M      NaN    8,180,068,059      BR
# 98      99.0      Speed Records       45.5M      NaN   30,587,436,800      IN
# 99     100.0              Zhong       45.5M      NaN   17,998,163,730      US
# 100     50.5                NaN         NaN      NaN              NaN     NaN
#
# [67 rows x 6 columns]

# %%
data = data.dropna(subset=['Uploads'])

# %%
data
# Out:
#     Ranking                    Username Subscribers  Uploads            Views  \
# 0       1.0                     MrBeast        336M    838.0   66,853,633,536
# 2       3.0    Cocomelon-Nursery Rhymes        186M   1370.0  194,361,752,276
# 3       4.0              Youtube Movies        185M      0.0                0
# 5       6.0                 Vlad & Niki        129M    796.0   99,291,499,729
# 7       8.0                 Like Nastya        124M    918.0  108,128,507,997
# 8       9.0                       Music        121M      0.0                0
# 12     13.0                Stokes Twins        102M    335.0   16,139,307,959
# 15     16.0                   Blackpink       95.4M    603.0   37,502,831,600
# 16     17.0                   ChuChu Tv       94.3M    832.0   53,265,415,943
# 17     18.0                      Gaming       92.9M      0.0                0
# 24     25.0                      Sports       74.7M      0.0                0
# ...

# %%
# Find the channel with the highest number of uploads
highest_uploads_channel = data.loc[data['Uploads'].idxmax()]
print("Channel with the highest uploads:")
print(highest_uploads_channel[['Username', 'Uploads']])
# Out:
# Channel with the highest uploads:
# Username    Cocomelon-Nursery Rhymes
# Uploads                       1370.0
# Name: 2, dtype: object
